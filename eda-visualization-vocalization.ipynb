# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

from IPython.display import Audio
import librosa

# %%
taxonomy = '/kaggle/input/birdclef-2023/eBird_Taxonomy_v2021.csv'
metadata = '/kaggle/input/birdclef-2023/train_metadata.csv'

# %%
dftax = pd.read_csv(taxonomy)
dfmeta = pd.read_csv(metadata)

# %%
dftax
# Out:
#        TAXON_ORDER CATEGORY SPECIES_CODE         PRIMARY_COM_NAME  \
# 0                1  species      ostric2           Common Ostrich
# 1                6  species      ostric3           Somali Ostrich
# 2                7    slash       y00934    Common/Somali Ostrich
# 3                8  species      grerhe1             Greater Rhea
# 4               14  species      lesrhe2              Lesser Rhea
# ...            ...      ...          ...                      ...
# 16748        34694  species      slcgro1   Slate-colored Grosbeak
# 16749        34697  species      bltgro2  Black-throated Grosbeak
# 16750        34698     spuh      saltat1             saltator sp.
# 16751        34699     spuh      passer1            passerine sp.
# 16752        35000     spuh        bird1                 bird sp.
#
#                              SCI_NAME            ORDER1  \
# 0                    Struthio camelus  Struthioniformes
# 1              Struthio molybdophanes  Struthioniformes
# ...

# %%
dfmeta
# Out:
#       primary_label secondary_labels              type  latitude  longitude  \
# 0           abethr1               []          ['song']    4.3906    38.2788
# 1           abethr1               []          ['call']   -2.9524    38.2921
# 2           abethr1               []          ['song']   -2.9524    38.2921
# 3           abethr1               []          ['song']   -2.9524    38.2921
# 4           abethr1               []  ['call', 'song']   -2.9524    38.2921
# ...             ...              ...               ...       ...        ...
# 16936       yewgre1               []              ['']   -1.2502    29.7971
# 16937       yewgre1               []              ['']   -1.2489    29.7923
# 16938       yewgre1               []              ['']   -1.2433    29.7844
# 16939       yewgre1               []              ['']    0.0452    36.3699
# 16940       yewgre1               []              ['']   -0.3986    37.3087
#
# ...

# %%
example_instance = dfmeta.iloc[0, :]

# %%
fig = px.scatter_mapbox(dfmeta, lat="latitude", lon="longitude", hover_name="primary_label",
                        color_discrete_sequence=["fuchsia"], zoom=3, height=1000, width=1000)
fig.update_layout(mapbox_style="open-street-map")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
fig = px.density_mapbox(dfmeta, lat='latitude', lon='longitude', radius=2, hover_name="primary_label", zoom=1, height=1000, width=1000)
fig.update_layout(mapbox_style="stamen-terrain")
# Out:
# <div>                            <div id="aaf87015-acd5-4a02-aedd-62f692a0935a" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaf87015-acd5-4a02-aedd-62f692a0935a")) {                    Plotly.newPlot(                        "aaf87015-acd5-4a02-aedd-62f692a0935a",                        [{"coloraxis":"coloraxis","hovertemplate":"<b>%{hovertext}</b><br><br>latitude=%{lat}<br>longitude=%{lon}<extra></extra>","hovertext":["abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abethr1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1","abhori1",
# ...

# %%
example_instance['filename']
# Out:
# 'abethr1/XC128013.ogg'

# %%
audio_abe, sr_abe = librosa.load("/kaggle/input/birdclef-2023/train_audio/" + example_instance['filename'])

# %%
Audio(data=audio_abe, rate=sr_abe)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio_abe
# Out:
# array([-2.0752661e-06, -6.3113657e-07,  1.0178218e-06, ...,
#        -3.8138585e-04,  6.7974709e-04,  7.5442006e-04], dtype=float32)

# %%
audio_abe.shape[0]
# Out:
# 1005696

# %%
sr_abe
# Out:
# 22050

# %%
audio_abe.shape[0] / sr_abe
# Out:
# 45.60979591836735

# %%
sns.lineplot(audio_abe)
# Out:
# <AxesSubplot:>
